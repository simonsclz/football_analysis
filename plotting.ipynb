# %%
# a simple plot for the PDP-example

import matplotlib.pyplot as plt


temps = list(range(20, 35+1))
sold_cones = [150 + k*15 for k in range(1, 17)]

plt.scatter(temps, [0] * len(temps), marker='|', color='black')

plt.xlabel("Temperatur [°C]")
plt.ylabel("Anzahl verkaufter Eiskugeln")

plt.plot(temps, sold_cones)
